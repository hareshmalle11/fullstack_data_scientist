# %% [markdown]
# #  NLP Pipeline
#
# ## 1️⃣ Data Collection
# 1. Raw Text Data
#
# ## 2️⃣ Text Preprocessing
#
# 1. Tokenization
# 2. Lowercasing
# 4. Regular Expressions (RegEx cleanup)
#
# ## 3️⃣ Text Preprocessing 2
# 1. Stemming
# 2. Lemmatization
# 3. Stop words
#
# ## 4️⃣ Feature Vectors
# 1. One hot encoding
# 2. Bag of Words
# 3. TF_IDF
# 4. Word to Vector
# 5. Average Word to Vector
#
# ## 5️⃣ ML Algortihm
# - Apply Machine Learning or Deep Learning algorithms
# - Perform training and prediction
