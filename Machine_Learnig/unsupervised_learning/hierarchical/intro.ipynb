# %% [markdown]
#
#    ![image.png](attachment:image.png)
#
# - step 1 : for each datapoint intially consder each one as new cluster
# - step 2 : find the nearest point and create new cluster
# - step 3 : keep on going the process [ step 2] until we get a single cluster
#
# 1. Agglomerative approach : bottom to top
# 2. Divisive approach : top to bottom

# %% [markdown]
# - linkage typers(technique to check distance b/w clusters)
# 1. single linkage : min distance data points
#
#     ![image.png](attachment:image.png)
# 2. complete linkage : max distance data points
# 3. average linkage : mean distance

# %% [markdown]
# ### dendogram
# - finds out hoe many cluster we should form
#
#     ![image-2.png](attachment:image-2.png)
#
# - select longest vertical line such that no horizontal line passes through it.
#
#     ![image.png](attachment:image.png)

# %% [markdown]
# ### pdf content
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
# ![image-9.png](attachment:image-9.png)
